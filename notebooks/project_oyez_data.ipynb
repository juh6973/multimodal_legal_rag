# %% [markdown]
# # Project Oyez data
# Dataset of U.S. Supreme Court Oral Arguments.

# %% [markdown]
# ## Import libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# A method for case list by term

# %%
def get_case_list(term, per_page=250) -> list[dict]:
    """
    Retrieve a list of cases for a given Supreme Court term
    using pagination. Returns a list of case JSON objects.
    """
    base_url = "https://api.oyez.org/cases"
    url = f"{base_url}?per_page={per_page}&filter=term:{term}"
    response = requests.get(url)
        
    if response.status_code != 200: return None
    data = response.json()
    
    if len(data) == 0: return None
    
    return data

# %% [markdown]
# A method for getting case details

# %%
def get_case_details(url: str) -> dict:
    """
    Retrieve case details based on link.
    Returns a JSON object.
    """
    response = requests.get(url)
        
    if response.status_code != 200: return None
    data = response.json()

    audio_links = data.get("oral_argument_audio")
    if audio_links is not None: audio_links = [audio["href"] for audio in audio_links]

    return {
        "facts_of_the_case": data.get("facts_of_the_case"),
        "question": data.get("question"),
        "conclusion": data.get("conclusion"),
        "description": data.get("description"),
        "audio_links": audio_links,
    }

# %% [markdown]
# Get the cases from 2000 to 2024

# %%
df = []
start_year, end_year = 2000, 2024
for year in range(start_year, end_year+1):
    
    cases = get_case_list(year)
    print(f"Fetched cases {len(cases)} for term: {year}")
    for case in cases:

        case_url = case["href"]
        details = get_case_details(case_url)
        df.append({
            "id": case["ID"],
            "name": case["name"],
            "facts_of_the_case": details["facts_of_the_case"],
            "question": details["question"],
            "conclusion": details["conclusion"],
            "description": details["description"],
            "audio_links": details["audio_links"],
        })
# Out:
# Fetched cases 86 for term: 2000
# Fetched cases 84 for term: 2001
# Fetched cases 85 for term: 2002
# Fetched cases 81 for term: 2003
# Fetched cases 80 for term: 2004
# Fetched cases 89 for term: 2005
# Fetched cases 77 for term: 2006
# Fetched cases 75 for term: 2007
# Fetched cases 83 for term: 2008
# Fetched cases 87 for term: 2009
# Fetched cases 82 for term: 2010
# Fetched cases 80 for term: 2011
# Fetched cases 80 for term: 2012
# Fetched cases 78 for term: 2013
# Fetched cases 77 for term: 2014
# Fetched cases 81 for term: 2015
# Fetched cases 72 for term: 2016
# Fetched cases 79 for term: 2017
# Fetched cases 76 for term: 2018
# Fetched cases 61 for term: 2019
# Fetched cases 64 for term: 2020
# Fetched cases 67 for term: 2021
# Fetched cases 62 for term: 2022
# Fetched cases 62 for term: 2023
# Fetched cases 63 for term: 2024

# %%
df = pd.DataFrame(df)
# Out:
#        id                                               name  \
# 0   54829                              Arizona v. California
# 1   54856                  United States v. Mead Corporation
# 2   54857  Cooper Industries, Inc. v. Leatherman Tool Gro...
# 3   54858                                     Lopez v. Davis
# 4   54859                               Egelhoff v. Egelhoff
# 5   54860                                   Artuz v. Bennett
# 6   54861  C. & L. Enterprises, Inc. v. Citizen Band Pota...
# 7   54862                     Ferguson v. City of Charleston
# 8   54863                                  Hunt v. Cromartie
# 9   54864                           Daniels v. United States
# 10  54866                            Calcano-Martinez v. INS
# 11  54867                United States v. United Foods, Inc.
# 12  54868                                 Kansas v. Colorado
# 13  54869      City News & Novelty, Inc. v. City of Waukesha
# 14  54870                              Alexander v. Sandoval
# 15  54871                         Cleveland v. United States
# 2   <p>No. In an 8-1 opinion delivered by Justice ...
# 3   <p>Yes. In a 6-3 opinion delivered by Justice ...
# 4   <p>Yes. In a 7-2 opinion delivered by Justice ...
# 5   <p>Yes. In a unanimous opinion delivered by Ju...
# 6   <p>Yes. In a unanimous opinion delivered by Ju...
# 7   <p>Yes. In a 6-3 opinion delivered by Justice ...
# 8   <p>Yes. In a 5-4 opinion delivered by Justice ...
# 9   <p>No. In a 5-4 opinion delivered by Justice S...
# 10  <p>Yes. In a 5-4 opinion delivered by Justice ...
# 11  <p>Yes. In a 6-3 opinion delivered by Justice ...
# 12  <p>No, yes, no, no, and no. In a unanimous opi...
# 13  <p>The Court did not answer the question. In a...
# 14  <p>No. In a 5-4 opinion delivered by Justice A...
# 15  <p>No. In a unanimous opinion delivered by Jus...
# 16  <p>No. In a 5-4 opinion delivered by Justice S...
# 17  <p>No. In a 5-4 opinion delivered by Chief Jus...
# 18  <p>No. In a unanimous opinion delivered by Jus...
# 19  <p>Yes. In an opinion delivered by Chief Justi...
# 20  <p>No. In an opinion delivered by Justice John...
# 21  <p>No. In a 5-4 opinion delivered by Justice A...
# 22  <p>Yes. In a unanimous opinion delivered by Ju...
# 23  <p>No. In an 8-1 opinion delivered by Justice ...
# 24  <p>No. In a unanimous per curiam opinion, the ...
#
#                                           description  \
# 0                       Supplemental decree approved.
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24  Absent evidence of individuals personally subj...
#
#                                           audio_links
# 0   [https://api.oyez.org/case_media/oral_argument...
# 1   [https://api.oyez.org/case_media/oral_argument...
# 2   [https://api.oyez.org/case_media/oral_argument...
# 3   [https://api.oyez.org/case_media/oral_argument...
# 4   [https://api.oyez.org/case_media/oral_argument...
# 5   [https://api.oyez.org/case_media/oral_argument...
# 6   [https://api.oyez.org/case_media/oral_argument...
# 7   [https://api.oyez.org/case_media/oral_argument...
# 8   [https://api.oyez.org/case_media/oral_argument...
# 9   [https://api.oyez.org/case_media/oral_argument...
# 10  [https://api.oyez.org/case_media/oral_argument...
# 11  [https://api.oyez.org/case_media/oral_argument...
# 12  [https://api.oyez.org/case_media/oral_argument...
# 13  [https://api.oyez.org/case_media/oral_argument...
# 14  [https://api.oyez.org/case_media/oral_argument...
# 15  [https://api.oyez.org/case_media/oral_argument...
# 16  [https://api.oyez.org/case_media/oral_argument...
# 17  [https://api.oyez.org/case_media/oral_argument...
# 18  [https://api.oyez.org/case_media/oral_argument...
# 19  [https://api.oyez.org/case_media/oral_argument...
# 20  [https://api.oyez.org/case_media/oral_argument...
# 21  [https://api.oyez.org/case_media/oral_argument...
# 22  [https://api.oyez.org/case_media/oral_argument...
# 23  [https://api.oyez.org/case_media/oral_argument...
# 24                                               None

# %% [markdown]
# remove .html tags

# %%
df["facts_of_the_case"] = df["facts_of_the_case"].str.replace(r'<[^>]*>', '', regex=True)
df["question"] = df["question"].str.replace(r'<[^>]*>', '', regex=True)
df["conclusion"] = df["conclusion"].str.replace(r'<[^>]*>', '', regex=True)
df["description"] = df["description"].str.replace(r'<[^>]*>', '', regex=True)

# %% [markdown]
# Save the dataframe

# %%
data_path = "./data/oyez_data.csv"
df.to_csv(data_path, index=False)
